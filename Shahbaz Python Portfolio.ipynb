# %% [markdown]
# **Program No 1**

# %%
number1 = input('Enter first number:')
number2 = input('Enter second number:')
sum = float(number1) + float(number2)
print('Sum of {0} and {1} is {2}'.format(number1,number2,sum))
# Out:
# Enter first number:7
# Enter second number:9
# Sum of 7 and 9 is 16.0

# %% [markdown]
# **Program No 2**

# %%
from rich.console import Console
list_1 = [100,200,300,400,500,700,500,450,650]
list_2 = [50,250,340,400,500,30,500,150,650]
list_3 = [101,250,300,1000,500,70,500,450,60]
list_4 = [100,200,300,400,500,700,500,450,650]
max_value = max(list_1,list_2,list_3,list_4)
console.print("[bold]Max Value[/bold]")
# print("Max Value")
print(max_value)
print('\n')
console.print("[bold]Min Value[/bold]")
min_value = (list_1,list_2,list_3,list_4)
print(min_value)
# Out:
# Max Value
# [101, 250, 300, 1000, 500, 70, 500, 450, 60]
# Min Value
# ([100, 200, 300, 400, 500, 700, 500, 450, 650], [50, 250, 340, 400, 500, 30, 500, 150, 650], [101, 250, 300, 1000, 500, 70, 500, 450, 60], [100, 200, 300, 400, 500, 700, 500, 450, 650])

# %% [markdown]
# **Program No 3**

# %%
def factorial(shahbaz):
  return 1 if (shahbaz==1 or shahbaz==0) else shahbaz * factorial(shahbaz - 1)
arshad = factorial(5)
print("Factorial is", arshad)
# Out:
# Factorial is 120

# %% [markdown]
# **Program No 4**
